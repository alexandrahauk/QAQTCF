# %%
mol =
# Out:
# [1, 5]

# %%
[p for p, c in enumerate('11010100') if c == '1']
# Out:
# [0, 1, 3, 5]

# %%
class test:
    def __getitem__(self, index):
        print(index)
        return 0

a = test()
print(a[0,1])
# Out:
# (0, 1)
# 0
